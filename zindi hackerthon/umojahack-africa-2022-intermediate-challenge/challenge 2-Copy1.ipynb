# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is A20E-6E0F
#
#  Directory of C:\Users\Naku\Desktop\books\zindi hackerthon\umojahack-africa-2022-intermediate-challenge
#
# 03/20/2022  03:17 AM    <DIR>          .
# 03/20/2022  03:17 AM    <DIR>          ..
# 03/20/2022  02:47 AM    <DIR>          .ipynb_checkpoints
# 03/20/2022  02:11 AM            76,378 Baseline.csv
# 03/20/2022  02:19 AM           209,990 challenge 2.ipynb
# 03/20/2022  03:17 AM            16,657 challenge 2-Copy1.ipynb
# 03/18/2022  07:04 AM               793 DataDictionary.csv
# 03/19/2022  12:45 PM           114,458 pee.ipynb
# 03/18/2022  07:04 AM         4,069,463 policies.csv
# 03/18/2022  07:04 AM            72,358 SampleSubmission.csv
# 03/18/2022  07:04 AM           534,268 test.csv
# 03/18/2022  07:04 AM         1,312,345 train.csv
# 03/20/2022  02:46 AM            28,512 Untitled.ipynb
# 03/19/2022  04:40 AM           230,003 Zimnat_starternotebook.ipynb
#               11 File(s)      6,665,225 bytes
#                3 Dir(s)  270,282,153,984 bytes free
#  Volume in drive C has no label.
#  Volume Serial Number is A20E-6E0F
#
#  Directory of C:\Users\Naku\Desktop\books\zindi hackerthon\umojahack-africa-2022-intermediate-challenge
#
# 03/20/2022  03:17 AM    <DIR>          .
# 03/20/2022  03:17 AM    <DIR>          ..
# 03/20/2022  02:47 AM    <DIR>          .ipynb_checkpoints
# 03/20/2022  02:11 AM            76,378 Baseline.csv
# 03/20/2022  02:19 AM           209,990 challenge 2.ipynb
# 03/20/2022  03:17 AM            16,657 challenge 2-Copy1.ipynb
# 03/18/2022  07:04 AM               793 DataDictionary.csv
# 03/19/2022  12:45 PM           114,458 pee.ipynb
# 03/18/2022  07:04 AM         4,069,463 policies.csv
# 03/18/2022  07:04 AM            72,358 SampleSubmission.csv
# 03/18/2022  07:04 AM           534,268 test.csv
# 03/18/2022  07:04 AM         1,312,345 train.csv
# 03/20/2022  02:46 AM            28,512 Untitled.ipynb
# 03/19/2022  04:40 AM           230,003 Zimnat_starternotebook.ipynb
#               11 File(s)      6,665,225 bytes
#                3 Dir(s)  270,282,153,984 bytes free

# %%
#loading data
dataInfo = pd.read_csv('DataDictionary.csv')
policy = pd.read_csv('policies.csv')
test = pd.read_csv('test.csv')
train = pd.read_csv('train.csv')
samplesubmission = pd.read_csv('SampleSubmission.csv')

# %%
#viewing the data
train.head()
# Out:
#           claim_id policy_number  claim_number  sum_insured    product  \
# 0  ID_JZ7QWRHH57RO  pol000009680  claim0011359     300000.0  prod00027
# 1  ID_KQ5TJMVLJ4EP  pol000006869  claim0005272      16000.0  prod00005
# 2  ID_NYHI7WJGGIAE  pol000006135  claim0004147       3000.0  prod00029
# 3  ID_ROMMDCXYUXN5  pol000008991  claim0009962       6000.0  prod00005
# 4  ID_2OTD9NX8L73D  pol000007768  claim0007346      26850.0  prod00015
#
#      agent class_of_business risk_type   loss_date client_type  \
# 0  ag00068          cob00031   rt00006  2021-05-13      ct0003
# 1  ag00226          cob00010   rt00032  2018-05-13      ct0003
# 2  ag00037          cob00010   rt00026  2018-08-18      ct0003
# 3  ag00037          cob00009   rt00032  2018-12-20      ct0003
# 4  ag00226          cob00034   rt00023  2018-11-07      ct0001
#
#   renewal_frequency primary_cause secondary_cause   branch    target
# 0            rf0001        pc0007         sc00022  br00006  82150.00
# 1            rf0001        pc0007         sc00023  br00002   3780.24
# 2            rf0001        pc0007         sc00024  br00002   2196.50
# 3            rf0001        pc0007         sc00021  br00001    105.67
# 4            rf0001        pc0007         sc00021  br00001   1605.64
#           claim_id policy_number  claim_number  sum_insured    product  \
# 0  ID_JZ7QWRHH57RO  pol000009680  claim0011359     300000.0  prod00027
# 1  ID_KQ5TJMVLJ4EP  pol000006869  claim0005272      16000.0  prod00005
# 2  ID_NYHI7WJGGIAE  pol000006135  claim0004147       3000.0  prod00029
# 3  ID_ROMMDCXYUXN5  pol000008991  claim0009962       6000.0  prod00005
# 4  ID_2OTD9NX8L73D  pol000007768  claim0007346      26850.0  prod00015
#
#      agent class_of_business risk_type   loss_date client_type  \
# 0  ag00068          cob00031   rt00006  2021-05-13      ct0003
# 1  ag00226          cob00010   rt00032  2018-05-13      ct0003
# 2  ag00037          cob00010   rt00026  2018-08-18      ct0003
# 3  ag00037          cob00009   rt00032  2018-12-20      ct0003
# 4  ag00226          cob00034   rt00023  2018-11-07      ct0001
#
#   renewal_frequency primary_cause secondary_cause   branch    target
# 0            rf0001        pc0007         sc00022  br00006  82150.00
# 1            rf0001        pc0007         sc00023  br00002   3780.24
# 2            rf0001        pc0007         sc00024  br00002   2196.50
# 3            rf0001        pc0007         sc00021  br00001    105.67
# 4            rf0001        pc0007         sc00021  br00001   1605.64

# %%
policy.head()
# Out:
#   policy_number product_code               trans_date  \
# 0  pol000006995    prod00033  2017-07-01 08:24:55.800
# 1  pol000009828    prod00005  2017-07-01 09:04:02.217
# 2  pol000009828    prod00005  2017-07-01 09:04:02.217
# 3  pol000007729    prod00005  2017-07-01 09:36:53.843
# 4  pol000007729    prod00005  2017-07-01 09:36:53.843
#
#                  from_date                  to_date    agent  \
# 0  2017-07-01 00:00:00.000  2018-07-01 00:00:00.000  ag00005
# 1  2017-07-03 00:00:00.000  2017-11-02 00:00:00.000  ag00226
# 2  2017-07-03 00:00:00.000  2017-11-02 00:00:00.000  ag00226
# 3  2017-07-01 00:00:00.000  2017-10-31 00:00:00.000  ag00005
# 4  2017-07-01 00:00:00.000  2017-10-31 00:00:00.000  ag00005
#
#   class_of_business client_type renewal_frequency   branch
# 0          cob00035      ct0001            rf0002  br00002
# 1          cob00009      ct0003            rf0001  br00006
# 2          cob00031      ct0003            rf0001  br00006
# 3          cob00031      ct0003            rf0001  br00002
# 4          cob00009      ct0003            rf0001  br00002
#   policy_number product_code               trans_date  \
# 0  pol000006995    prod00033  2017-07-01 08:24:55.800
# 1  pol000009828    prod00005  2017-07-01 09:04:02.217
# 2  pol000009828    prod00005  2017-07-01 09:04:02.217
# 3  pol000007729    prod00005  2017-07-01 09:36:53.843
# 4  pol000007729    prod00005  2017-07-01 09:36:53.843
#
#                  from_date                  to_date    agent  \
# 0  2017-07-01 00:00:00.000  2018-07-01 00:00:00.000  ag00005
# 1  2017-07-03 00:00:00.000  2017-11-02 00:00:00.000  ag00226
# 2  2017-07-03 00:00:00.000  2017-11-02 00:00:00.000  ag00226
# 3  2017-07-01 00:00:00.000  2017-10-31 00:00:00.000  ag00005
# 4  2017-07-01 00:00:00.000  2017-10-31 00:00:00.000  ag00005
#
#   class_of_business client_type renewal_frequency   branch
# 0          cob00035      ct0001            rf0002  br00002
# 1          cob00009      ct0003            rf0001  br00006
# 2          cob00031      ct0003            rf0001  br00006
# 3          cob00031      ct0003            rf0001  br00002
# 4          cob00009      ct0003            rf0001  br00002

# %%
policy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30371 entries, 0 to 30370
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   policy_number      30371 non-null  object
#  1   product_code       30371 non-null  object
#  2   trans_date         30371 non-null  object
#  3   from_date          30371 non-null  object
#  4   to_date            30371 non-null  object
#  5   agent              30371 non-null  object
#  6   class_of_business  30325 non-null  object
#  7   client_type        30371 non-null  object
#  8   renewal_frequency  30371 non-null  object
#  9   branch             30371 non-null  object
# dtypes: object(10)
# memory usage: 1.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30371 entries, 0 to 30370
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   policy_number      30371 non-null  object
#  1   product_code       30371 non-null  object
#  2   trans_date         30371 non-null  object
#  3   from_date          30371 non-null  object
#  4   to_date            30371 non-null  object
#  5   agent              30371 non-null  object
#  6   class_of_business  30325 non-null  object
#  7   client_type        30371 non-null  object
#  8   renewal_frequency  30371 non-null  object
#  9   branch             30371 non-null  object
# dtypes: object(10)
# memory usage: 1.2+ MB

# %%
# Convert datetime variables to datetime objects
policy.from_date = pd.to_datetime(policy.from_date, errors='coerce')
policy.trans_date = pd.to_datetime(policy.trans_date, errors='coerce')


# Confirm that the dates have been converted successfully 
policy.from_date.describe()
# Out:
# count                   30371
# unique                   1431
# top       2018-02-01 00:00:00
# freq                     1122
# first     2017-01-01 00:00:00
# last      2021-11-17 00:00:00
# Name: from_date, dtype: object
# count                   30371
# unique                   1431
# top       2018-02-01 00:00:00
# freq                     1122
# first     2017-01-01 00:00:00
# last      2021-11-17 00:00:00
# Name: from_date, dtype: object

# %%
# Extract day, month and year from the loss date column
# day
policy['trans_date_day'] =policy.trans_date.dt.month

# month
policy['trans_date_month'] = policy.trans_date.dt.month
 
# year
policy['trans_date_year'] = policy.trans_date.dt.year
# day
policy['from_date_day'] =policy.from_date.dt.day

# month
policy['from_date_month'] = policy.from_date.dt.month
 
# year
policy['from_date_year'] = policy.from_date.dt.year

# Preview engineered date features
#train[['loss_date', 'loss_date_day', 'loss_date_month', 'loss_date_year']].head()# Extract day, month and year from the loss date column
# day
#train['loss_date_day'] = train.loss_date.dt.day

# month
#train['loss_date_month'] = train.loss_date.dt.month
 
# year
#train['loss_date_year'] = train.loss_date.dt.year

# Preview engineered date features
#train[['loss_date', 'loss_date_day', 'loss_date_month', 'loss_date_year']].head()

# %%
policy
# Out:
#       policy_number product_code              trans_date  from_date  \
# 0      pol000006995    prod00033 2017-07-01 08:24:55.800 2017-07-01
# 1      pol000009828    prod00005 2017-07-01 09:04:02.217 2017-07-03
# 2      pol000009828    prod00005 2017-07-01 09:04:02.217 2017-07-03
# 3      pol000007729    prod00005 2017-07-01 09:36:53.843 2017-07-01
# 4      pol000007729    prod00005 2017-07-01 09:36:53.843 2017-07-01
# ...             ...          ...                     ...        ...
# 30366  pol000005856    prod00015 2021-11-01 13:03:44.110 2021-11-01
# 30367  pol000009519    prod00027 2021-11-01 14:33:18.620 2021-10-01
# 30368  pol000007723    prod00015 2021-11-01 15:12:18.000 2021-11-01
# 30369  pol000006085    prod00015 2021-11-01 15:54:55.943 2021-10-01
# 30370  pol000005913    prod00015 2021-11-01 16:02:25.817 2021-10-22
#
#                        to_date    agent class_of_business client_type  \
# 0      2018-07-01 00:00:00.000  ag00005          cob00035      ct0001
# 1      2017-11-02 00:00:00.000  ag00226          cob00009      ct0003
# 2      2017-11-02 00:00:00.000  ag00226          cob00031      ct0003
# 3      2017-10-31 00:00:00.000  ag00005          cob00031      ct0003
# 4      2017-10-31 00:00:00.000  ag00005          cob00009      ct0003
# ...                        ...      ...               ...         ...
# 30366  2022-02-28 00:00:00.000  ag00006          cob00034      ct0001
# 30367  2022-09-30 00:00:00.000  ag00066          cob00031      ct0003
# 30368  2021-11-30 00:00:00.000  ag00021          cob00034      ct0001
# 30369  2021-10-31 00:00:00.000  ag00004          cob00034      ct0001
# 30370  2022-01-31 00:00:00.000  ag00011          cob00034      ct0001
#
#       renewal_frequency   branch  trans_date_day  trans_date_month  \
# 0                rf0002  br00002               7                 7
# 1                rf0001  br00006               7                 7
# 2                rf0001  br00006               7                 7
# 3                rf0001  br00002               7                 7
# 4                rf0001  br00002               7                 7
# ...                 ...      ...             ...               ...
# 30366            rf0001  br00002              11                11
# 30367            rf0002  br00001              11                11
# 30368            rf0005  br00001              11                11
# 30369            rf0005  br00002              11                11
# 30370            rf0001  br00002              11                11
#
#        trans_date_year  from_date_day  from_date_month  from_date_year
# 0                 2017              1                7            2017
# 1                 2017              3                7            2017
# 2                 2017              3                7            2017
# 3                 2017              1                7            2017
# 4                 2017              1                7            2017
# ...                ...            ...              ...             ...
# 30366             2021              1               11            2021
# 30367             2021              1               10            2021
# 30368             2021              1               11            2021
# 30369             2021              1               10            2021
# 30370             2021             22               10            2021
#
# [30371 rows x 16 columns]
#       policy_number product_code              trans_date  from_date  \
# 0      pol000006995    prod00033 2017-07-01 08:24:55.800 2017-07-01
# 1      pol000009828    prod00005 2017-07-01 09:04:02.217 2017-07-03
# 2      pol000009828    prod00005 2017-07-01 09:04:02.217 2017-07-03
# 3      pol000007729    prod00005 2017-07-01 09:36:53.843 2017-07-01
# 4      pol000007729    prod00005 2017-07-01 09:36:53.843 2017-07-01
# ...             ...          ...                     ...        ...
# 30366  pol000005856    prod00015 2021-11-01 13:03:44.110 2021-11-01
# 30367  pol000009519    prod00027 2021-11-01 14:33:18.620 2021-10-01
# 30368  pol000007723    prod00015 2021-11-01 15:12:18.000 2021-11-01
# 30369  pol000006085    prod00015 2021-11-01 15:54:55.943 2021-10-01
# 30370  pol000005913    prod00015 2021-11-01 16:02:25.817 2021-10-22
#
#                        to_date    agent class_of_business client_type  \
# 0      2018-07-01 00:00:00.000  ag00005          cob00035      ct0001
# 1      2017-11-02 00:00:00.000  ag00226          cob00009      ct0003
# 2      2017-11-02 00:00:00.000  ag00226          cob00031      ct0003
# 3      2017-10-31 00:00:00.000  ag00005          cob00031      ct0003
# 4      2017-10-31 00:00:00.000  ag00005          cob00009      ct0003
# ...                        ...      ...               ...         ...
# 30366  2022-02-28 00:00:00.000  ag00006          cob00034      ct0001
# 30367  2022-09-30 00:00:00.000  ag00066          cob00031      ct0003
# 30368  2021-11-30 00:00:00.000  ag00021          cob00034      ct0001
# 30369  2021-10-31 00:00:00.000  ag00004          cob00034      ct0001
# 30370  2022-01-31 00:00:00.000  ag00011          cob00034      ct0001
#
#       renewal_frequency   branch  trans_date_day  trans_date_month  \
# 0                rf0002  br00002               7                 7
# 1                rf0001  br00006               7                 7
# 2                rf0001  br00006               7                 7
# 3                rf0001  br00002               7                 7
# 4                rf0001  br00002               7                 7
# ...                 ...      ...             ...               ...
# 30366            rf0001  br00002              11                11
# 30367            rf0002  br00001              11                11
# 30368            rf0005  br00001              11                11
# 30369            rf0005  br00002              11                11
# 30370            rf0001  br00002              11                11
#
#        trans_date_year  from_date_day  from_date_month  from_date_year
# 0                 2017              1                7            2017
# 1                 2017              3                7            2017
# 2                 2017              3                7            2017
# 3                 2017              1                7            2017
# 4                 2017              1                7            2017
# ...                ...            ...              ...             ...
# 30366             2021              1               11            2021
# 30367             2021              1               10            2021
# 30368             2021              1               11            2021
# 30369             2021              1               10            2021
# 30370             2021             22               10            2021
#
# [30371 rows x 16 columns]

# %%
policy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30371 entries, 0 to 30370
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   policy_number      30371 non-null  object
#  1   product_code       30371 non-null  object
#  2   trans_date         30371 non-null  datetime64[ns]
#  3   from_date          30371 non-null  datetime64[ns]
#  4   to_date            30371 non-null  object
#  5   agent              30371 non-null  object
#  6   class_of_business  30325 non-null  object
#  7   client_type        30371 non-null  object
#  8   renewal_frequency  30371 non-null  object
#  9   branch             30371 non-null  object
#  10  trans_date_day     30371 non-null  int64
#  11  trans_date_month   30371 non-null  int64
#  12  trans_date_year    30371 non-null  int64
#  13  from_date_day      30371 non-null  int64
#  14  from_date_month    30371 non-null  int64
#  15  from_date_year     30371 non-null  int64
# dtypes: datetime64[ns](2), int64(6), object(8)
# memory usage: 2.8+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30371 entries, 0 to 30370
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   policy_number      30371 non-null  object
#  1   product_code       30371 non-null  object
#  2   trans_date         30371 non-null  datetime64[ns]
#  3   from_date          30371 non-null  datetime64[ns]
#  4   to_date            30371 non-null  object
#  5   agent              30371 non-null  object
#  6   class_of_business  30325 non-null  object
#  7   client_type        30371 non-null  object
#  8   renewal_frequency  30371 non-null  object
#  9   branch             30371 non-null  object
#  10  trans_date_day     30371 non-null  int64
#  11  trans_date_month   30371 non-null  int64
#  12  trans_date_year    30371 non-null  int64
#  13  from_date_day      30371 non-null  int64
#  14  from_date_month    30371 non-null  int64
#  15  from_date_year     30371 non-null  int64
# dtypes: datetime64[ns](2), int64(6), object(8)
# memory usage: 2.8+ MB

# %%
policy.drop("from_date",axis = 1,inplace = True)

# %%
policy.drop("trans_date",axis = 1,inplace = True)

# %%
# Convert categorical variables to categorical objects
cat_cols = policy.columns.difference(['from_date_year', 'from_date_month', 'from_date_day','trans_date_year','trans_date_month','trans_date_day',' trans_date',' from_date']).tolist()

# Preview categorical variables
policy[cat_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30371 entries, 0 to 30370
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   agent              9376 non-null   category
#  1   branch             9376 non-null   category
#  2   class_of_business  9376 non-null   category
#  3   client_type        9376 non-null   category
#  4   policy_number      9290 non-null   category
#  5   product_code       30371 non-null  object
#  6   renewal_frequency  30371 non-null  object
#  7   to_date            30371 non-null  object
# dtypes: category(5), object(3)
# memory usage: 616.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30371 entries, 0 to 30370
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   agent              9376 non-null   category
#  1   branch             9376 non-null   category
#  2   class_of_business  9376 non-null   category
#  3   client_type        9376 non-null   category
#  4   policy_number      9290 non-null   category
#  5   product_code       30371 non-null  object
#  6   renewal_frequency  30371 non-null  object
#  7   to_date            30371 non-null  object
# dtypes: category(5), object(3)
# memory usage: 616.0+ KB

# %%
policy[cat_cols] = policy[cat_cols].apply(lambda x: x.fillna(x.value_counts().index[0]))

# %%
for col in cat_cols:
  policy[col] = train[col].astype('category')

# Confirm
policy.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'product_code'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-2db37d9a6302> in <module>
#       1 for col in cat_cols:
# ----> 2   policy[col] = train[col].astype('category')
#       3
#       4 # Confirm
#       5 policy.info()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'product_code'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'product_code'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-2db37d9a6302> in <module>
#       1 for col in cat_cols:
# ----> 2   policy[col] = train[col].astype('category')
#       3
#       4 # Confirm
#       5 policy.info()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'product_code'

# %%
policy[cat_cols] = policy[cat_cols].apply(lambda x: x.fillna(x.value_counts().index[0]))

# %%
policy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30371 entries, 0 to 30370
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   policy_number      30371 non-null  category
#  1   product_code       30371 non-null  object
#  2   to_date            30371 non-null  object
#  3   agent              30371 non-null  category
#  4   class_of_business  30371 non-null  category
#  5   client_type        30371 non-null  category
#  6   renewal_frequency  30371 non-null  object
#  7   branch             30371 non-null  category
#  8   trans_date_day     30371 non-null  int64
#  9   trans_date_month   30371 non-null  int64
#  10  trans_date_year    30371 non-null  int64
#  11  from_date_day      30371 non-null  int64
#  12  from_date_month    30371 non-null  int64
#  13  from_date_year     30371 non-null  int64
# dtypes: category(5), int64(6), object(3)
# memory usage: 2.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30371 entries, 0 to 30370
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   policy_number      30371 non-null  category
#  1   product_code       30371 non-null  object
#  2   to_date            30371 non-null  object
#  3   agent              30371 non-null  category
#  4   class_of_business  30371 non-null  category
#  5   client_type        30371 non-null  category
#  6   renewal_frequency  30371 non-null  object
#  7   branch             30371 non-null  category
#  8   trans_date_day     30371 non-null  int64
#  9   trans_date_month   30371 non-null  int64
#  10  trans_date_year    30371 non-null  int64
#  11  from_date_day      30371 non-null  int64
#  12  from_date_month    30371 non-null  int64
#  13  from_date_year     30371 non-null  int64
# dtypes: category(5), int64(6), object(3)
# memory usage: 2.0+ MB

# %%
train
# Out:
#              claim_id policy_number  claim_number  sum_insured    product  \
# 0     ID_JZ7QWRHH57RO  pol000009680  claim0011359     300000.0  prod00027
# 1     ID_KQ5TJMVLJ4EP  pol000006869  claim0005272      16000.0  prod00005
# 2     ID_NYHI7WJGGIAE  pol000006135  claim0004147       3000.0  prod00029
# 3     ID_ROMMDCXYUXN5  pol000008991  claim0009962       6000.0  prod00005
# 4     ID_2OTD9NX8L73D  pol000007768  claim0007346      26850.0  prod00015
# ...               ...           ...           ...          ...        ...
# 9371  ID_A5ETUPPQDFLS  pol000006054  claim0003743      42000.0  prod00015
# 9372  ID_Z3OGUWI7T2GC  pol000006715  claim0005088       6800.0  prod00005
# 9373  ID_GSJDAJCABSBZ  pol000008236  claim0008976       5000.0  prod00005
# 9374  ID_8B7YNBEKXHJW  pol000006847  claim0005250       6000.0  prod00005
# 9375  ID_8OB2QWUC664M  pol000007450  claim0006249      10000.0  prod00027
#
#         agent class_of_business risk_type   loss_date client_type  \
# 0     ag00068          cob00031   rt00006  2021-05-13      ct0003
# 1     ag00226          cob00010   rt00032  2018-05-13      ct0003
# 2     ag00037          cob00010   rt00026  2018-08-18      ct0003
# 3     ag00037          cob00009   rt00032  2018-12-20      ct0003
# 4     ag00226          cob00034   rt00023  2018-11-07      ct0001
# ...       ...               ...       ...         ...         ...
# 9371  ag00037          cob00034   rt00023  2019-09-02      ct0001
# 9372  ag00064          cob00009   rt00032  2018-05-12      ct0003
# 9373  ag00064          cob00009   rt00032  2018-07-28      ct0003
# 9374  ag00037          cob00009   rt00032  2018-08-16      ct0003
# 9375  ag00226          cob00010   rt00006  2019-09-07      ct0003
#
#      renewal_frequency primary_cause secondary_cause   branch    target
# 0               rf0001        pc0007         sc00022  br00006  82150.00
# 1               rf0001        pc0007         sc00023  br00002   3780.24
# 2               rf0001        pc0007         sc00024  br00002   2196.50
# 3               rf0001        pc0007         sc00021  br00001    105.67
# 4               rf0001        pc0007         sc00021  br00001   1605.64
# ...                ...           ...             ...      ...       ...
# 9371            rf0002        pc0007         sc00021  br00002    205.68
# 9372            rf0002        pc0007         sc00021  br00002   1133.32
# 9373            rf0001        pc0007         sc00029  br00001   2176.00
# 9374            rf0001        pc0007         sc00022  br00002    851.40
# 9375            rf0002        pc0007         sc00023  br00001   1410.00
#
# [9376 rows x 15 columns]
#              claim_id policy_number  claim_number  sum_insured    product  \
# 0     ID_JZ7QWRHH57RO  pol000009680  claim0011359     300000.0  prod00027
# 1     ID_KQ5TJMVLJ4EP  pol000006869  claim0005272      16000.0  prod00005
# 2     ID_NYHI7WJGGIAE  pol000006135  claim0004147       3000.0  prod00029
# 3     ID_ROMMDCXYUXN5  pol000008991  claim0009962       6000.0  prod00005
# 4     ID_2OTD9NX8L73D  pol000007768  claim0007346      26850.0  prod00015
# ...               ...           ...           ...          ...        ...
# 9371  ID_A5ETUPPQDFLS  pol000006054  claim0003743      42000.0  prod00015
# 9372  ID_Z3OGUWI7T2GC  pol000006715  claim0005088       6800.0  prod00005
# 9373  ID_GSJDAJCABSBZ  pol000008236  claim0008976       5000.0  prod00005
# 9374  ID_8B7YNBEKXHJW  pol000006847  claim0005250       6000.0  prod00005
# 9375  ID_8OB2QWUC664M  pol000007450  claim0006249      10000.0  prod00027
#
#         agent class_of_business risk_type   loss_date client_type  \
# 0     ag00068          cob00031   rt00006  2021-05-13      ct0003
# 1     ag00226          cob00010   rt00032  2018-05-13      ct0003
# 2     ag00037          cob00010   rt00026  2018-08-18      ct0003
# 3     ag00037          cob00009   rt00032  2018-12-20      ct0003
# 4     ag00226          cob00034   rt00023  2018-11-07      ct0001
# ...       ...               ...       ...         ...         ...
# 9371  ag00037          cob00034   rt00023  2019-09-02      ct0001
# 9372  ag00064          cob00009   rt00032  2018-05-12      ct0003
# 9373  ag00064          cob00009   rt00032  2018-07-28      ct0003
# 9374  ag00037          cob00009   rt00032  2018-08-16      ct0003
# 9375  ag00226          cob00010   rt00006  2019-09-07      ct0003
#
#      renewal_frequency primary_cause secondary_cause   branch    target
# 0               rf0001        pc0007         sc00022  br00006  82150.00
# 1               rf0001        pc0007         sc00023  br00002   3780.24
# 2               rf0001        pc0007         sc00024  br00002   2196.50
# 3               rf0001        pc0007         sc00021  br00001    105.67
# 4               rf0001        pc0007         sc00021  br00001   1605.64
# ...                ...           ...             ...      ...       ...
# 9371            rf0002        pc0007         sc00021  br00002    205.68
# 9372            rf0002        pc0007         sc00021  br00002   1133.32
# 9373            rf0001        pc0007         sc00029  br00001   2176.00
# 9374            rf0001        pc0007         sc00022  br00002    851.40
# 9375            rf0002        pc0007         sc00023  br00001   1410.00
#
# [9376 rows x 15 columns]

# %%
train
# Out:
#              claim_id policy_number  claim_number  sum_insured    product  \
# 0     ID_JZ7QWRHH57RO  pol000009680  claim0011359     300000.0  prod00027
# 1     ID_KQ5TJMVLJ4EP  pol000006869  claim0005272      16000.0  prod00005
# 2     ID_NYHI7WJGGIAE  pol000006135  claim0004147       3000.0  prod00029
# 3     ID_ROMMDCXYUXN5  pol000008991  claim0009962       6000.0  prod00005
# 4     ID_2OTD9NX8L73D  pol000007768  claim0007346      26850.0  prod00015
# ...               ...           ...           ...          ...        ...
# 9371  ID_A5ETUPPQDFLS  pol000006054  claim0003743      42000.0  prod00015
# 9372  ID_Z3OGUWI7T2GC  pol000006715  claim0005088       6800.0  prod00005
# 9373  ID_GSJDAJCABSBZ  pol000008236  claim0008976       5000.0  prod00005
# 9374  ID_8B7YNBEKXHJW  pol000006847  claim0005250       6000.0  prod00005
# 9375  ID_8OB2QWUC664M  pol000007450  claim0006249      10000.0  prod00027
#
#         agent class_of_business risk_type   loss_date client_type  \
# 0     ag00068          cob00031   rt00006  2021-05-13      ct0003
# 1     ag00226          cob00010   rt00032  2018-05-13      ct0003
# 2     ag00037          cob00010   rt00026  2018-08-18      ct0003
# 3     ag00037          cob00009   rt00032  2018-12-20      ct0003
# 4     ag00226          cob00034   rt00023  2018-11-07      ct0001
# ...       ...               ...       ...         ...         ...
# 9371  ag00037          cob00034   rt00023  2019-09-02      ct0001
# 9372  ag00064          cob00009   rt00032  2018-05-12      ct0003
# 9373  ag00064          cob00009   rt00032  2018-07-28      ct0003
# 9374  ag00037          cob00009   rt00032  2018-08-16      ct0003
# 9375  ag00226          cob00010   rt00006  2019-09-07      ct0003
#
#      renewal_frequency primary_cause secondary_cause   branch    target
# 0               rf0001        pc0007         sc00022  br00006  82150.00
# 1               rf0001        pc0007         sc00023  br00002   3780.24
# 2               rf0001        pc0007         sc00024  br00002   2196.50
# 3               rf0001        pc0007         sc00021  br00001    105.67
# 4               rf0001        pc0007         sc00021  br00001   1605.64
# ...                ...           ...             ...      ...       ...
# 9371            rf0002        pc0007         sc00021  br00002    205.68
# 9372            rf0002        pc0007         sc00021  br00002   1133.32
# 9373            rf0001        pc0007         sc00029  br00001   2176.00
# 9374            rf0001        pc0007         sc00022  br00002    851.40
# 9375            rf0002        pc0007         sc00023  br00001   1410.00
#
# [9376 rows x 15 columns]
#              claim_id policy_number  claim_number  sum_insured    product  \
# 0     ID_JZ7QWRHH57RO  pol000009680  claim0011359     300000.0  prod00027
# 1     ID_KQ5TJMVLJ4EP  pol000006869  claim0005272      16000.0  prod00005
# 2     ID_NYHI7WJGGIAE  pol000006135  claim0004147       3000.0  prod00029
# 3     ID_ROMMDCXYUXN5  pol000008991  claim0009962       6000.0  prod00005
# 4     ID_2OTD9NX8L73D  pol000007768  claim0007346      26850.0  prod00015
# ...               ...           ...           ...          ...        ...
# 9371  ID_A5ETUPPQDFLS  pol000006054  claim0003743      42000.0  prod00015
# 9372  ID_Z3OGUWI7T2GC  pol000006715  claim0005088       6800.0  prod00005
# 9373  ID_GSJDAJCABSBZ  pol000008236  claim0008976       5000.0  prod00005
# 9374  ID_8B7YNBEKXHJW  pol000006847  claim0005250       6000.0  prod00005
# 9375  ID_8OB2QWUC664M  pol000007450  claim0006249      10000.0  prod00027
#
#         agent class_of_business risk_type   loss_date client_type  \
# 0     ag00068          cob00031   rt00006  2021-05-13      ct0003
# 1     ag00226          cob00010   rt00032  2018-05-13      ct0003
# 2     ag00037          cob00010   rt00026  2018-08-18      ct0003
# 3     ag00037          cob00009   rt00032  2018-12-20      ct0003
# 4     ag00226          cob00034   rt00023  2018-11-07      ct0001
# ...       ...               ...       ...         ...         ...
# 9371  ag00037          cob00034   rt00023  2019-09-02      ct0001
# 9372  ag00064          cob00009   rt00032  2018-05-12      ct0003
# 9373  ag00064          cob00009   rt00032  2018-07-28      ct0003
# 9374  ag00037          cob00009   rt00032  2018-08-16      ct0003
# 9375  ag00226          cob00010   rt00006  2019-09-07      ct0003
#
#      renewal_frequency primary_cause secondary_cause   branch    target
# 0               rf0001        pc0007         sc00022  br00006  82150.00
# 1               rf0001        pc0007         sc00023  br00002   3780.24
# 2               rf0001        pc0007         sc00024  br00002   2196.50
# 3               rf0001        pc0007         sc00021  br00001    105.67
# 4               rf0001        pc0007         sc00021  br00001   1605.64
# ...                ...           ...             ...      ...       ...
# 9371            rf0002        pc0007         sc00021  br00002    205.68
# 9372            rf0002        pc0007         sc00021  br00002   1133.32
# 9373            rf0001        pc0007         sc00029  br00001   2176.00
# 9374            rf0001        pc0007         sc00022  br00002    851.40
# 9375            rf0002        pc0007         sc00023  br00001   1410.00
#
# [9376 rows x 15 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9376 entries, 0 to 9375
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   claim_id           9376 non-null   object
#  1   policy_number      9290 non-null   object
#  2   claim_number       9376 non-null   object
#  3   sum_insured        9376 non-null   float64
#  4   product            9376 non-null   object
#  5   agent              9376 non-null   object
#  6   class_of_business  9376 non-null   object
#  7   risk_type          9376 non-null   object
#  8   loss_date          9376 non-null   object
#  9   client_type        9376 non-null   object
#  10  renewal_frequency  9376 non-null   object
#  11  primary_cause      9376 non-null   object
#  12  secondary_cause    9376 non-null   object
#  13  branch             9376 non-null   object
#  14  target             9376 non-null   float64
# dtypes: float64(2), object(13)
# memory usage: 622.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9376 entries, 0 to 9375
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   claim_id           9376 non-null   object
#  1   policy_number      9290 non-null   object
#  2   claim_number       9376 non-null   object
#  3   sum_insured        9376 non-null   float64
#  4   product            9376 non-null   object
#  5   agent              9376 non-null   object
#  6   class_of_business  9376 non-null   object
#  7   risk_type          9376 non-null   object
#  8   loss_date          9376 non-null   object
#  9   client_type        9376 non-null   object
#  10  renewal_frequency  9376 non-null   object
#  11  primary_cause      9376 non-null   object
#  12  secondary_cause    9376 non-null   object
#  13  branch             9376 non-null   object
#  14  target             9376 non-null   float64
# dtypes: float64(2), object(13)
# memory usage: 622.7+ KB

# %% [markdown]
# FOCUSSING ON THE TRAIN DATA--VISUALISATION AND ANALYSIS

# %%
train.head()
# Out:
#           claim_id policy_number  claim_number  sum_insured    product  \
# 0  ID_JZ7QWRHH57RO  pol000009680  claim0011359     300000.0  prod00027
# 1  ID_KQ5TJMVLJ4EP  pol000006869  claim0005272      16000.0  prod00005
# 2  ID_NYHI7WJGGIAE  pol000006135  claim0004147       3000.0  prod00029
# 3  ID_ROMMDCXYUXN5  pol000008991  claim0009962       6000.0  prod00005
# 4  ID_2OTD9NX8L73D  pol000007768  claim0007346      26850.0  prod00015
#
#      agent class_of_business risk_type   loss_date client_type  \
# 0  ag00068          cob00031   rt00006  2021-05-13      ct0003
# 1  ag00226          cob00010   rt00032  2018-05-13      ct0003
# 2  ag00037          cob00010   rt00026  2018-08-18      ct0003
# 3  ag00037          cob00009   rt00032  2018-12-20      ct0003
# 4  ag00226          cob00034   rt00023  2018-11-07      ct0001
#
#   renewal_frequency primary_cause secondary_cause   branch    target
# 0            rf0001        pc0007         sc00022  br00006  82150.00
# 1            rf0001        pc0007         sc00023  br00002   3780.24
# 2            rf0001        pc0007         sc00024  br00002   2196.50
# 3            rf0001        pc0007         sc00021  br00001    105.67
# 4            rf0001        pc0007         sc00021  br00001   1605.64
#           claim_id policy_number  claim_number  sum_insured    product  \
# 0  ID_JZ7QWRHH57RO  pol000009680  claim0011359     300000.0  prod00027
# 1  ID_KQ5TJMVLJ4EP  pol000006869  claim0005272      16000.0  prod00005
# 2  ID_NYHI7WJGGIAE  pol000006135  claim0004147       3000.0  prod00029
# 3  ID_ROMMDCXYUXN5  pol000008991  claim0009962       6000.0  prod00005
# 4  ID_2OTD9NX8L73D  pol000007768  claim0007346      26850.0  prod00015
#
#      agent class_of_business risk_type   loss_date client_type  \
# 0  ag00068          cob00031   rt00006  2021-05-13      ct0003
# 1  ag00226          cob00010   rt00032  2018-05-13      ct0003
# 2  ag00037          cob00010   rt00026  2018-08-18      ct0003
# 3  ag00037          cob00009   rt00032  2018-12-20      ct0003
# 4  ag00226          cob00034   rt00023  2018-11-07      ct0001
#
#   renewal_frequency primary_cause secondary_cause   branch    target
# 0            rf0001        pc0007         sc00022  br00006  82150.00
# 1            rf0001        pc0007         sc00023  br00002   3780.24
# 2            rf0001        pc0007         sc00024  br00002   2196.50
# 3            rf0001        pc0007         sc00021  br00001    105.67
# 4            rf0001        pc0007         sc00021  br00001   1605.64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9376 entries, 0 to 9375
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   claim_id           9376 non-null   object
#  1   policy_number      9290 non-null   object
#  2   claim_number       9376 non-null   object
#  3   sum_insured        9376 non-null   float64
#  4   product            9376 non-null   object
#  5   agent              9376 non-null   object
#  6   class_of_business  9376 non-null   object
#  7   risk_type          9376 non-null   object
#  8   loss_date          9376 non-null   object
#  9   client_type        9376 non-null   object
#  10  renewal_frequency  9376 non-null   object
#  11  primary_cause      9376 non-null   object
#  12  secondary_cause    9376 non-null   object
#  13  branch             9376 non-null   object
#  14  target             9376 non-null   float64
# dtypes: float64(2), object(13)
# memory usage: 622.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9376 entries, 0 to 9375
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   claim_id           9376 non-null   object
#  1   policy_number      9290 non-null   object
#  2   claim_number       9376 non-null   object
#  3   sum_insured        9376 non-null   float64
#  4   product            9376 non-null   object
#  5   agent              9376 non-null   object
#  6   class_of_business  9376 non-null   object
#  7   risk_type          9376 non-null   object
#  8   loss_date          9376 non-null   object
#  9   client_type        9376 non-null   object
#  10  renewal_frequency  9376 non-null   object
#  11  primary_cause      9376 non-null   object
#  12  secondary_cause    9376 non-null   object
#  13  branch             9376 non-null   object
#  14  target             9376 non-null   float64
# dtypes: float64(2), object(13)
# memory usage: 622.7+ KB

# %%
train.isnull().sum()
# Out:
# claim_id              0
# policy_number        86
# claim_number          0
# sum_insured           0
# product               0
# agent                 0
# class_of_business     0
# risk_type             0
# loss_date             0
# client_type           0
# renewal_frequency     0
# primary_cause         0
# secondary_cause       0
# branch                0
# target                0
# dtype: int64
# claim_id              0
# policy_number        86
# claim_number          0
# sum_insured           0
# product               0
# agent                 0
# class_of_business     0
# risk_type             0
# loss_date             0
# client_type           0
# renewal_frequency     0
# primary_cause         0
# secondary_cause       0
# branch                0
# target                0
# dtype: int64

# %%
# Plot missing values in train set
ax = train.isna().sum().sort_values().plot(kind = 'barh', figsize = (9, 10))
plt.title('Percentage of Missing Values Per Column in Train Set', fontdict={'size':15})
for p in ax.patches:
    percentage ='{:,.0f}%'.format((p.get_width()/train.shape[0])*100)
    width, height =p.get_width(),p.get_height()
    x=p.get_x()+width+0.02
    y=p.get_y()+height/2
    ax.annotate(percentage,(x,y))

# %%
#checking for duplications
train.duplicated().sum()
# Out:
# 0
# 0

# %%
# A box plot showing outliers
plt.figure(figsize=(12, 6))
sns.boxplot(train.target)
plt.title('Target Variable Distribution');

# %%
# Convert datetime variables to datetime objects
train.loss_date = pd.to_datetime(train.loss_date, errors='coerce')

# Confirm that the dates have been converted successfully 
train.loss_date.describe()
# Out:
# count                    9376
# unique                   1359
# top       2019-08-20 00:00:00
# freq                       83
# first     2018-01-01 00:00:00
# last      2021-10-22 00:00:00
# Name: loss_date, dtype: object
# count                    9376
# unique                   1359
# top       2019-08-20 00:00:00
# freq                       83
# first     2018-01-01 00:00:00
# last      2021-10-22 00:00:00
# Name: loss_date, dtype: object

# %%
# Convert categorical variables to categorical objects
cat_cols = train.columns.difference(['claim_id', 'loss_date', 'sum_insured', 'target']).tolist()

# Preview categorical variables
train[cat_cols].head()
# Out:
#      agent   branch  claim_number class_of_business client_type policy_number  \
# 0  ag00068  br00006  claim0011359          cob00031      ct0003  pol000009680
# 1  ag00226  br00002  claim0005272          cob00010      ct0003  pol000006869
# 2  ag00037  br00002  claim0004147          cob00010      ct0003  pol000006135
# 3  ag00037  br00001  claim0009962          cob00009      ct0003  pol000008991
# 4  ag00226  br00001  claim0007346          cob00034      ct0001  pol000007768
#
#   primary_cause    product renewal_frequency risk_type secondary_cause
# 0        pc0007  prod00027            rf0001   rt00006         sc00022
# 1        pc0007  prod00005            rf0001   rt00032         sc00023
# 2        pc0007  prod00029            rf0001   rt00026         sc00024
# 3        pc0007  prod00005            rf0001   rt00032         sc00021
# 4        pc0007  prod00015            rf0001   rt00023         sc00021
#      agent   branch  claim_number class_of_business client_type policy_number  \
# 0  ag00068  br00006  claim0011359          cob00031      ct0003  pol000009680
# 1  ag00226  br00002  claim0005272          cob00010      ct0003  pol000006869
# 2  ag00037  br00002  claim0004147          cob00010      ct0003  pol000006135
# 3  ag00037  br00001  claim0009962          cob00009      ct0003  pol000008991
# 4  ag00226  br00001  claim0007346          cob00034      ct0001  pol000007768
#
#   primary_cause    product renewal_frequency risk_type secondary_cause
# 0        pc0007  prod00027            rf0001   rt00006         sc00022
# 1        pc0007  prod00005            rf0001   rt00032         sc00023
# 2        pc0007  prod00029            rf0001   rt00026         sc00024
# 3        pc0007  prod00005            rf0001   rt00032         sc00021
# 4        pc0007  prod00015            rf0001   rt00023         sc00021

# %%
# Fill in missing values in categorical variables with the most common
train[cat_cols] = train[cat_cols].apply(lambda x: x.fillna(x.value_counts().index[0]))

# Convert
for col in cat_cols:
  train[col] = train[col].astype('category')

# Confirm
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9376 entries, 0 to 9375
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   claim_id           9376 non-null   object
#  1   policy_number      9376 non-null   category
#  2   claim_number       9376 non-null   category
#  3   sum_insured        9376 non-null   float64
#  4   product            9376 non-null   category
#  5   agent              9376 non-null   category
#  6   class_of_business  9376 non-null   category
#  7   risk_type          9376 non-null   category
#  8   loss_date          9376 non-null   datetime64[ns]
#  9   client_type        9376 non-null   category
#  10  renewal_frequency  9376 non-null   category
#  11  primary_cause      9376 non-null   category
#  12  secondary_cause    9376 non-null   category
#  13  branch             9376 non-null   category
#  14  target             9376 non-null   float64
# dtypes: category(11), datetime64[ns](1), float64(2), object(1)
# memory usage: 627.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9376 entries, 0 to 9375
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   claim_id           9376 non-null   object
#  1   policy_number      9376 non-null   category
#  2   claim_number       9376 non-null   category
#  3   sum_insured        9376 non-null   float64
#  4   product            9376 non-null   category
#  5   agent              9376 non-null   category
#  6   class_of_business  9376 non-null   category
#  7   risk_type          9376 non-null   category
#  8   loss_date          9376 non-null   datetime64[ns]
#  9   client_type        9376 non-null   category
#  10  renewal_frequency  9376 non-null   category
#  11  primary_cause      9376 non-null   category
#  12  secondary_cause    9376 non-null   category
#  13  branch             9376 non-null   category
#  14  target             9376 non-null   float64
# dtypes: category(11), datetime64[ns](1), float64(2), object(1)
# memory usage: 627.1+ KB

# %%
train
# Out:
#              claim_id policy_number  claim_number  sum_insured    product  \
# 0     ID_JZ7QWRHH57RO  pol000009680  claim0011359     300000.0  prod00027
# 1     ID_KQ5TJMVLJ4EP  pol000006869  claim0005272      16000.0  prod00005
# 2     ID_NYHI7WJGGIAE  pol000006135  claim0004147       3000.0  prod00029
# 3     ID_ROMMDCXYUXN5  pol000008991  claim0009962       6000.0  prod00005
# 4     ID_2OTD9NX8L73D  pol000007768  claim0007346      26850.0  prod00015
# ...               ...           ...           ...          ...        ...
# 9371  ID_A5ETUPPQDFLS  pol000006054  claim0003743      42000.0  prod00015
# 9372  ID_Z3OGUWI7T2GC  pol000006715  claim0005088       6800.0  prod00005
# 9373  ID_GSJDAJCABSBZ  pol000008236  claim0008976       5000.0  prod00005
# 9374  ID_8B7YNBEKXHJW  pol000006847  claim0005250       6000.0  prod00005
# 9375  ID_8OB2QWUC664M  pol000007450  claim0006249      10000.0  prod00027
#
#         agent class_of_business risk_type  loss_date client_type  \
# 0     ag00068          cob00031   rt00006 2021-05-13      ct0003
# 1     ag00226          cob00010   rt00032 2018-05-13      ct0003
# 2     ag00037          cob00010   rt00026 2018-08-18      ct0003
# 3     ag00037          cob00009   rt00032 2018-12-20      ct0003
# 4     ag00226          cob00034   rt00023 2018-11-07      ct0001
# ...       ...               ...       ...        ...         ...
# 9371  ag00037          cob00034   rt00023 2019-09-02      ct0001
# 9372  ag00064          cob00009   rt00032 2018-05-12      ct0003
# 9373  ag00064          cob00009   rt00032 2018-07-28      ct0003
# 9374  ag00037          cob00009   rt00032 2018-08-16      ct0003
# 9375  ag00226          cob00010   rt00006 2019-09-07      ct0003
#
#      renewal_frequency primary_cause secondary_cause   branch    target
# 0               rf0001        pc0007         sc00022  br00006  82150.00
# 1               rf0001        pc0007         sc00023  br00002   3780.24
# 2               rf0001        pc0007         sc00024  br00002   2196.50
# 3               rf0001        pc0007         sc00021  br00001    105.67
# 4               rf0001        pc0007         sc00021  br00001   1605.64
# ...                ...           ...             ...      ...       ...
# 9371            rf0002        pc0007         sc00021  br00002    205.68
# 9372            rf0002        pc0007         sc00021  br00002   1133.32
# 9373            rf0001        pc0007         sc00029  br00001   2176.00
# 9374            rf0001        pc0007         sc00022  br00002    851.40
# 9375            rf0002        pc0007         sc00023  br00001   1410.00
#
# [9376 rows x 15 columns]
#              claim_id policy_number  claim_number  sum_insured    product  \
# 0     ID_JZ7QWRHH57RO  pol000009680  claim0011359     300000.0  prod00027
# 1     ID_KQ5TJMVLJ4EP  pol000006869  claim0005272      16000.0  prod00005
# 2     ID_NYHI7WJGGIAE  pol000006135  claim0004147       3000.0  prod00029
# 3     ID_ROMMDCXYUXN5  pol000008991  claim0009962       6000.0  prod00005
# 4     ID_2OTD9NX8L73D  pol000007768  claim0007346      26850.0  prod00015
# ...               ...           ...           ...          ...        ...
# 9371  ID_A5ETUPPQDFLS  pol000006054  claim0003743      42000.0  prod00015
# 9372  ID_Z3OGUWI7T2GC  pol000006715  claim0005088       6800.0  prod00005
# 9373  ID_GSJDAJCABSBZ  pol000008236  claim0008976       5000.0  prod00005
# 9374  ID_8B7YNBEKXHJW  pol000006847  claim0005250       6000.0  prod00005
# 9375  ID_8OB2QWUC664M  pol000007450  claim0006249      10000.0  prod00027
#
#         agent class_of_business risk_type  loss_date client_type  \
# 0     ag00068          cob00031   rt00006 2021-05-13      ct0003
# 1     ag00226          cob00010   rt00032 2018-05-13      ct0003
# 2     ag00037          cob00010   rt00026 2018-08-18      ct0003
# 3     ag00037          cob00009   rt00032 2018-12-20      ct0003
# 4     ag00226          cob00034   rt00023 2018-11-07      ct0001
# ...       ...               ...       ...        ...         ...
# 9371  ag00037          cob00034   rt00023 2019-09-02      ct0001
# 9372  ag00064          cob00009   rt00032 2018-05-12      ct0003
# 9373  ag00064          cob00009   rt00032 2018-07-28      ct0003
# 9374  ag00037          cob00009   rt00032 2018-08-16      ct0003
# 9375  ag00226          cob00010   rt00006 2019-09-07      ct0003
#
#      renewal_frequency primary_cause secondary_cause   branch    target
# 0               rf0001        pc0007         sc00022  br00006  82150.00
# 1               rf0001        pc0007         sc00023  br00002   3780.24
# 2               rf0001        pc0007         sc00024  br00002   2196.50
# 3               rf0001        pc0007         sc00021  br00001    105.67
# 4               rf0001        pc0007         sc00021  br00001   1605.64
# ...                ...           ...             ...      ...       ...
# 9371            rf0002        pc0007         sc00021  br00002    205.68
# 9372            rf0002        pc0007         sc00021  br00002   1133.32
# 9373            rf0001        pc0007         sc00029  br00001   2176.00
# 9374            rf0001        pc0007         sc00022  br00002    851.40
# 9375            rf0002        pc0007         sc00023  br00001   1410.00
#
# [9376 rows x 15 columns]

# %%
# Extract day, month and year from the loss date column
# day
train['loss_date_day'] = train.loss_date.dt.day

# month
train['loss_date_month'] = train.loss_date.dt.month
 
# year
train['loss_date_year'] = train.loss_date.dt.year

# Preview engineered date features
train[['loss_date', 'loss_date_day', 'loss_date_month', 'loss_date_year']].head()# Extract day, month and year from the loss date column
# day
train['loss_date_day'] = train.loss_date.dt.day

# month
train['loss_date_month'] = train.loss_date.dt.month
 
# year
train['loss_date_year'] = train.loss_date.dt.year

# Preview engineered date features
train[['loss_date', 'loss_date_day', 'loss_date_month', 'loss_date_year']].head()
# Out:
#    loss_date  loss_date_day  loss_date_month  loss_date_year
# 0 2021-05-13             13                5            2021
# 1 2018-05-13             13                5            2018
# 2 2018-08-18             18                8            2018
# 3 2018-12-20             20               12            2018
# 4 2018-11-07              7               11            2018
#    loss_date  loss_date_day  loss_date_month  loss_date_year
# 0 2021-05-13             13                5            2021
# 1 2018-05-13             13                5            2018
# 2 2018-08-18             18                8            2018
# 3 2018-12-20             20               12            2018
# 4 2018-11-07              7               11            2018

# %%
# Label encode categorical variables
for col in cat_cols:
  # Instantiate Labelencoder
  le = LabelEncoder()
  train[col] = le.fit_transform(train[col])

# Preview engineered train dataset
train.head()
# Out:
#           claim_id  policy_number  claim_number  sum_insured  product  agent  \
# 0  ID_JZ7QWRHH57RO           3070          7439     300000.0       26      4
# 1  ID_KQ5TJMVLJ4EP           1126          3469      16000.0        4      7
# 2  ID_NYHI7WJGGIAE            630          2799       3000.0       28      1
# 3  ID_ROMMDCXYUXN5           2546          6448       6000.0        4      1
# 4  ID_2OTD9NX8L73D           1767          4832      26850.0       14      7
#
#    class_of_business  risk_type  loss_date  client_type  renewal_frequency  \
# 0                 30          5 2021-05-13            2                  0
# 1                  9         31 2018-05-13            2                  0
# 2                  9         25 2018-08-18            2                  0
# 3                  8         31 2018-12-20            2                  0
# 4                 32         22 2018-11-07            0                  0
#
#    primary_cause  secondary_cause  branch    target  loss_date_day  \
# 0              6               20       5  82150.00             13
# 1              6               21       1   3780.24             13
# 2              6               22       1   2196.50             18
# 3              6               19       0    105.67             20
# 4              6               19       0   1605.64              7
#
#    loss_date_month  loss_date_year
# 0                5            2021
# 1                5            2018
# 2                8            2018
# 3               12            2018
# 4               11            2018
#           claim_id  policy_number  claim_number  sum_insured  product  agent  \
# 0  ID_JZ7QWRHH57RO           3070          7439     300000.0       26      4
# 1  ID_KQ5TJMVLJ4EP           1126          3469      16000.0        4      7
# 2  ID_NYHI7WJGGIAE            630          2799       3000.0       28      1
# 3  ID_ROMMDCXYUXN5           2546          6448       6000.0        4      1
# 4  ID_2OTD9NX8L73D           1767          4832      26850.0       14      7
#
#    class_of_business  risk_type  loss_date  client_type  renewal_frequency  \
# 0                 30          5 2021-05-13            2                  0
# 1                  9         31 2018-05-13            2                  0
# 2                  9         25 2018-08-18            2                  0
# 3                  8         31 2018-12-20            2                  0
# 4                 32         22 2018-11-07            0                  0
#
#    primary_cause  secondary_cause  branch    target  loss_date_day  \
# 0              6               20       5  82150.00             13
# 1              6               21       1   3780.24             13
# 2              6               22       1   2196.50             18
# 3              6               19       0    105.67             20
# 4              6               19       0   1605.64              7
#
#    loss_date_month  loss_date_year
# 0                5            2021
# 1                5            2018
# 2                8            2018
# 3               12            2018
# 4               11            2018

# %%
test = pd.merge(policy,test)

# %%
test
# Out:
#        policy_number product_code                  to_date    agent  \
# 0       pol000007768    prod00005  2017-10-31 00:00:00.000  ag00226
# 1       pol000007768    prod00005  2017-11-30 00:00:00.000  ag00226
# 2       pol000007768    prod00005  2017-12-31 00:00:00.000  ag00226
# 3       pol000007768    prod00028  2018-01-31 00:00:00.000  ag00226
# 4       pol000007768    prod00005  2018-02-28 00:00:00.000  ag00226
# ...              ...          ...                      ...      ...
# 843364  pol000006026    prod00002  2021-10-31 00:00:00.000  ag00037
# 843365  pol000006026    prod00015  2021-10-31 00:00:00.000  ag00037
# 843366  pol000006026    prod00015  2021-10-31 00:00:00.000  ag00037
# 843367  pol000006026    prod00015  2021-11-30 00:00:00.000  ag00037
# 843368  pol000006026    prod00015  2021-10-31 00:00:00.000  ag00037
#
#        class_of_business client_type renewal_frequency   branch  \
# 0               cob00034      ct0001            rf0001  br00001
# 1               cob00034      ct0001            rf0001  br00001
# 2               cob00034      ct0001            rf0001  br00001
# 3               cob00034      ct0001            rf0001  br00001
# 4               cob00034      ct0001            rf0001  br00001
# ...                  ...         ...               ...      ...
# 843364          cob00034      ct0001            rf0005  br00002
# 843365          cob00034      ct0001            rf0005  br00002
# 843366          cob00034      ct0001            rf0005  br00002
# 843367          cob00034      ct0001            rf0005  br00002
# 843368          cob00034      ct0001            rf0005  br00002
#
#         trans_date_day  trans_date_month  ...  from_date_month  \
# 0                    7                 7  ...                7
# 1                    8                 8  ...                8
# 2                    9                 9  ...                9
# 3                   10                10  ...               10
# 4                   11                11  ...               10
# ...                ...               ...  ...              ...
# 843364              10                10  ...               10
# 843365              10                10  ...               10
# 843366              10                10  ...               10
# 843367              11                11  ...               11
# 843368              11                11  ...               10
#
#         from_date_year         claim_id  claim_number sum_insured    product  \
# 0                 2017  ID_8F8WXY1EU1ZL  claim0007344     26850.0  prod00015
# 1                 2017  ID_8F8WXY1EU1ZL  claim0007344     26850.0  prod00015
# 2                 2017  ID_8F8WXY1EU1ZL  claim0007344     26850.0  prod00015
# 3                 2017  ID_8F8WXY1EU1ZL  claim0007344     26850.0  prod00015
# 4                 2017  ID_8F8WXY1EU1ZL  claim0007344     26850.0  prod00015
# ...                ...              ...           ...         ...        ...
# 843364            2021  ID_Q66FS565F7G8  claim0003487  15960000.0  prod00015
# 843365            2021  ID_Q66FS565F7G8  claim0003487  15960000.0  prod00015
# 843366            2021  ID_Q66FS565F7G8  claim0003487  15960000.0  prod00015
# 843367            2021  ID_Q66FS565F7G8  claim0003487  15960000.0  prod00015
# 843368            2021  ID_Q66FS565F7G8  claim0003487  15960000.0  prod00015
#
#         risk_type   loss_date primary_cause secondary_cause
# 0         rt00023  2018-09-08        pc0007         sc00023
# 1         rt00023  2018-09-08        pc0007         sc00023
# 2         rt00023  2018-09-08        pc0007         sc00023
# 3         rt00023  2018-09-08        pc0007         sc00023
# 4         rt00023  2018-09-08        pc0007         sc00023
# ...           ...         ...           ...             ...
# 843364    rt00023  2021-04-01        pc0007         sc00023
# 843365    rt00023  2021-04-01        pc0007         sc00023
# 843366    rt00023  2021-04-01        pc0007         sc00023
# 843367    rt00023  2021-04-01        pc0007         sc00023
# 843368    rt00023  2021-04-01        pc0007         sc00023
#
# [843369 rows x 22 columns]
#        policy_number product_code                  to_date    agent  \
# 0       pol000007768    prod00005  2017-10-31 00:00:00.000  ag00226
# 1       pol000007768    prod00005  2017-11-30 00:00:00.000  ag00226
# 2       pol000007768    prod00005  2017-12-31 00:00:00.000  ag00226
# 3       pol000007768    prod00028  2018-01-31 00:00:00.000  ag00226
# 4       pol000007768    prod00005  2018-02-28 00:00:00.000  ag00226
# ...              ...          ...                      ...      ...
# 843364  pol000006026    prod00002  2021-10-31 00:00:00.000  ag00037
# 843365  pol000006026    prod00015  2021-10-31 00:00:00.000  ag00037
# 843366  pol000006026    prod00015  2021-10-31 00:00:00.000  ag00037
# 843367  pol000006026    prod00015  2021-11-30 00:00:00.000  ag00037
# 843368  pol000006026    prod00015  2021-10-31 00:00:00.000  ag00037
#
#        class_of_business client_type renewal_frequency   branch  \
# 0               cob00034      ct0001            rf0001  br00001
# 1               cob00034      ct0001            rf0001  br00001
# 2               cob00034      ct0001            rf0001  br00001
# 3               cob00034      ct0001            rf0001  br00001
# 4               cob00034      ct0001            rf0001  br00001
# ...                  ...         ...               ...      ...
# 843364          cob00034      ct0001            rf0005  br00002
# 843365          cob00034      ct0001            rf0005  br00002
# 843366          cob00034      ct0001            rf0005  br00002
# 843367          cob00034      ct0001            rf0005  br00002
# 843368          cob00034      ct0001            rf0005  br00002
#
#         trans_date_day  trans_date_month  ...  from_date_month  \
# 0                    7                 7  ...                7
# 1                    8                 8  ...                8
# 2                    9                 9  ...                9
# 3                   10                10  ...               10
# 4                   11                11  ...               10
# ...                ...               ...  ...              ...
# 843364              10                10  ...               10
# 843365              10                10  ...               10
# 843366              10                10  ...               10
# 843367              11                11  ...               11
# 843368              11                11  ...               10
#
#         from_date_year         claim_id  claim_number sum_insured    product  \
# 0                 2017  ID_8F8WXY1EU1ZL  claim0007344     26850.0  prod00015
# 1                 2017  ID_8F8WXY1EU1ZL  claim0007344     26850.0  prod00015
# 2                 2017  ID_8F8WXY1EU1ZL  claim0007344     26850.0  prod00015
# 3                 2017  ID_8F8WXY1EU1ZL  claim0007344     26850.0  prod00015
# 4                 2017  ID_8F8WXY1EU1ZL  claim0007344     26850.0  prod00015
# ...                ...              ...           ...         ...        ...
# 843364            2021  ID_Q66FS565F7G8  claim0003487  15960000.0  prod00015
# 843365            2021  ID_Q66FS565F7G8  claim0003487  15960000.0  prod00015
# 843366            2021  ID_Q66FS565F7G8  claim0003487  15960000.0  prod00015
# 843367            2021  ID_Q66FS565F7G8  claim0003487  15960000.0  prod00015
# 843368            2021  ID_Q66FS565F7G8  claim0003487  15960000.0  prod00015
#
#         risk_type   loss_date primary_cause secondary_cause
# 0         rt00023  2018-09-08        pc0007         sc00023
# 1         rt00023  2018-09-08        pc0007         sc00023
# 2         rt00023  2018-09-08        pc0007         sc00023
# 3         rt00023  2018-09-08        pc0007         sc00023
# 4         rt00023  2018-09-08        pc0007         sc00023
# ...           ...         ...           ...             ...
# 843364    rt00023  2021-04-01        pc0007         sc00023
# 843365    rt00023  2021-04-01        pc0007         sc00023
# 843366    rt00023  2021-04-01        pc0007         sc00023
# 843367    rt00023  2021-04-01        pc0007         sc00023
# 843368    rt00023  2021-04-01        pc0007         sc00023
#
# [843369 rows x 22 columns]

# %% [markdown]
# Preproccessing test data

# %%
# Convert datetime variables to datetime objects
test.loss_date = pd.to_datetime(test.loss_date, errors='coerce')

# Fill in missing values in categorical variables with the most common
test[cat_cols] = test[cat_cols].apply(lambda x: x.fillna(x.value_counts().index[0]))

# Convert
for col in cat_cols:
  test[col] = test[col].astype('category')

# Extract day, month and year from the loss date column
test['loss_date_day'] = test.loss_date.dt.day #day

test['loss_date_month'] = test.loss_date.dt.month #month
 
test['loss_date_year'] = test.loss_date.dt.year #year

# Label encode categorical variables
for col in cat_cols:
  # Instantiate Labelencoder
  le = LabelEncoder()
  test[col] = le.fit_transform(test[col])

# Preview engineered test dataset
test.head()
# Out:
#    policy_number product_code                  to_date  agent  \
# 0            296    prod00005  2017-10-31 00:00:00.000      6
# 1            296    prod00005  2017-11-30 00:00:00.000      6
# 2            296    prod00005  2017-12-31 00:00:00.000      6
# 3            296    prod00028  2018-01-31 00:00:00.000      6
# 4            296    prod00005  2018-02-28 00:00:00.000      6
#
#    class_of_business  client_type  renewal_frequency  branch  trans_date_day  \
# 0                 19            0                  0       0               7
# 1                 19            0                  0       0               8
# 2                 19            0                  0       0               9
# 3                 19            0                  0       0              10
# 4                 19            0                  0       0              11
#
#    trans_date_month  ...  claim_number  sum_insured  product  risk_type  \
# 0                 7  ...          1189      26850.0       10         13
# 1                 8  ...          1189      26850.0       10         13
# 2                 9  ...          1189      26850.0       10         13
# 3                10  ...          1189      26850.0       10         13
# 4                11  ...          1189      26850.0       10         13
#
#    loss_date  primary_cause  secondary_cause  loss_date_day  loss_date_month  \
# 0 2018-09-08              6               20              8                9
# 1 2018-09-08              6               20              8                9
# 2 2018-09-08              6               20              8                9
# 3 2018-09-08              6               20              8                9
# 4 2018-09-08              6               20              8                9
#
#   loss_date_year
# 0           2018
# 1           2018
# 2           2018
# 3           2018
# 4           2018
#
# [5 rows x 25 columns]
#    policy_number product_code                  to_date  agent  \
# 0            296    prod00005  2017-10-31 00:00:00.000      6
# 1            296    prod00005  2017-11-30 00:00:00.000      6
# 2            296    prod00005  2017-12-31 00:00:00.000      6
# 3            296    prod00028  2018-01-31 00:00:00.000      6
# 4            296    prod00005  2018-02-28 00:00:00.000      6
#
#    class_of_business  client_type  renewal_frequency  branch  trans_date_day  \
# 0                 19            0                  0       0               7
# 1                 19            0                  0       0               8
# 2                 19            0                  0       0               9
# 3                 19            0                  0       0              10
# 4                 19            0                  0       0              11
#
#    trans_date_month  ...  claim_number  sum_insured  product  risk_type  \
# 0                 7  ...          1189      26850.0       10         13
# 1                 8  ...          1189      26850.0       10         13
# 2                 9  ...          1189      26850.0       10         13
# 3                10  ...          1189      26850.0       10         13
# 4                11  ...          1189      26850.0       10         13
#
#    loss_date  primary_cause  secondary_cause  loss_date_day  loss_date_month  \
# 0 2018-09-08              6               20              8                9
# 1 2018-09-08              6               20              8                9
# 2 2018-09-08              6               20              8                9
# 3 2018-09-08              6               20              8                9
# 4 2018-09-08              6               20              8                9
#
#   loss_date_year
# 0           2018
# 1           2018
# 2           2018
# 3           2018
# 4           2018
#
# [5 rows x 25 columns]

# %%
test
# Out:
#         policy_number product_code                  to_date  agent  \
# 0                 296    prod00005  2017-10-31 00:00:00.000      6
# 1                 296    prod00005  2017-11-30 00:00:00.000      6
# 2                 296    prod00005  2017-12-31 00:00:00.000      6
# 3                 296    prod00028  2018-01-31 00:00:00.000      6
# 4                 296    prod00005  2018-02-28 00:00:00.000      6
# ...               ...          ...                      ...    ...
# 843364            142    prod00002  2021-10-31 00:00:00.000      1
# 843365            142    prod00015  2021-10-31 00:00:00.000      1
# 843366            142    prod00015  2021-10-31 00:00:00.000      1
# 843367            142    prod00015  2021-11-30 00:00:00.000      1
# 843368            142    prod00015  2021-10-31 00:00:00.000      1
#
#         class_of_business  client_type  renewal_frequency  branch  \
# 0                      19            0                  0       0
# 1                      19            0                  0       0
# 2                      19            0                  0       0
# 3                      19            0                  0       0
# 4                      19            0                  0       0
# ...                   ...          ...                ...     ...
# 843364                 19            0                  4       1
# 843365                 19            0                  4       1
# 843366                 19            0                  4       1
# 843367                 19            0                  4       1
# 843368                 19            0                  4       1
#
#         trans_date_day  trans_date_month  ...  claim_number  sum_insured  \
# 0                    7                 7  ...          1189      26850.0
# 1                    8                 8  ...          1189      26850.0
# 2                    9                 9  ...          1189      26850.0
# 3                   10                10  ...          1189      26850.0
# 4                   11                11  ...          1189      26850.0
# ...                ...               ...  ...           ...          ...
# 843364              10                10  ...           713   15960000.0
# 843365              10                10  ...           713   15960000.0
# 843366              10                10  ...           713   15960000.0
# 843367              11                11  ...           713   15960000.0
# 843368              11                11  ...           713   15960000.0
#
#         product  risk_type  loss_date  primary_cause  secondary_cause  \
# 0            10         13 2018-09-08              6               20
# 1            10         13 2018-09-08              6               20
# 2            10         13 2018-09-08              6               20
# 3            10         13 2018-09-08              6               20
# 4            10         13 2018-09-08              6               20
# ...         ...        ...        ...            ...              ...
# 843364       10         13 2021-04-01              6               20
# 843365       10         13 2021-04-01              6               20
# 843366       10         13 2021-04-01              6               20
# 843367       10         13 2021-04-01              6               20
# 843368       10         13 2021-04-01              6               20
#
#         loss_date_day  loss_date_month loss_date_year
# 0                   8                9           2018
# 1                   8                9           2018
# 2                   8                9           2018
# 3                   8                9           2018
# 4                   8                9           2018
# ...               ...              ...            ...
# 843364              1                4           2021
# 843365              1                4           2021
# 843366              1                4           2021
# 843367              1                4           2021
# 843368              1                4           2021
#
# [843369 rows x 25 columns]
#         policy_number product_code                  to_date  agent  \
# 0                 296    prod00005  2017-10-31 00:00:00.000      6
# 1                 296    prod00005  2017-11-30 00:00:00.000      6
# 2                 296    prod00005  2017-12-31 00:00:00.000      6
# 3                 296    prod00028  2018-01-31 00:00:00.000      6
# 4                 296    prod00005  2018-02-28 00:00:00.000      6
# ...               ...          ...                      ...    ...
# 843364            142    prod00002  2021-10-31 00:00:00.000      1
# 843365            142    prod00015  2021-10-31 00:00:00.000      1
# 843366            142    prod00015  2021-10-31 00:00:00.000      1
# 843367            142    prod00015  2021-11-30 00:00:00.000      1
# 843368            142    prod00015  2021-10-31 00:00:00.000      1
#
#         class_of_business  client_type  renewal_frequency  branch  \
# 0                      19            0                  0       0
# 1                      19            0                  0       0
# 2                      19            0                  0       0
# 3                      19            0                  0       0
# 4                      19            0                  0       0
# ...                   ...          ...                ...     ...
# 843364                 19            0                  4       1
# 843365                 19            0                  4       1
# 843366                 19            0                  4       1
# 843367                 19            0                  4       1
# 843368                 19            0                  4       1
#
#         trans_date_day  trans_date_month  ...  claim_number  sum_insured  \
# 0                    7                 7  ...          1189      26850.0
# 1                    8                 8  ...          1189      26850.0
# 2                    9                 9  ...          1189      26850.0
# 3                   10                10  ...          1189      26850.0
# 4                   11                11  ...          1189      26850.0
# ...                ...               ...  ...           ...          ...
# 843364              10                10  ...           713   15960000.0
# 843365              10                10  ...           713   15960000.0
# 843366              10                10  ...           713   15960000.0
# 843367              11                11  ...           713   15960000.0
# 843368              11                11  ...           713   15960000.0
#
#         product  risk_type  loss_date  primary_cause  secondary_cause  \
# 0            10         13 2018-09-08              6               20
# 1            10         13 2018-09-08              6               20
# 2            10         13 2018-09-08              6               20
# 3            10         13 2018-09-08              6               20
# 4            10         13 2018-09-08              6               20
# ...         ...        ...        ...            ...              ...
# 843364       10         13 2021-04-01              6               20
# 843365       10         13 2021-04-01              6               20
# 843366       10         13 2021-04-01              6               20
# 843367       10         13 2021-04-01              6               20
# 843368       10         13 2021-04-01              6               20
#
#         loss_date_day  loss_date_month loss_date_year
# 0                   8                9           2018
# 1                   8                9           2018
# 2                   8                9           2018
# 3                   8                9           2018
# 4                   8                9           2018
# ...               ...              ...            ...
# 843364              1                4           2021
# 843365              1                4           2021
# 843366              1                4           2021
# 843367              1                4           2021
# 843368              1                4           2021
#
# [843369 rows x 25 columns]

# %% [markdown]
# Modelling

# %%
# Select main columns to be used in training
main_cols = train.columns.difference(['claim_id', 'loss_date', 'target']).tolist()
X = train[main_cols]
y = train.target

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=0)

# Train model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Check the MAE score of the model
print(f'LinearRegression MAE score on the X_test is: {mean_absolute_error(y_test, y_pred)}')
# Out:
# LinearRegression MAE score on the X_test is: 58703.297374475944
# LinearRegression MAE score on the X_test is: 58703.297374475944

# %%
X_train
# Out:
#       agent  branch  claim_number  class_of_business  client_type  \
# 976       0       0          7803                 32            0
# 8454      4       0          5671                  9            0
# 6544      7       0          5949                  8            2
# 6877      4       6          8982                 30            2
# 607       3       1          2112                 32            0
# ...     ...     ...           ...                ...          ...
# 7891      4       6          7875                 12            0
# 9225      7       0          4827                 32            0
# 4859      4       4          8908                 11            0
# 3264      7       0          3861                 30            2
# 2732      7       0          6460                  8            2
#
#       loss_date_day  loss_date_month  loss_date_year  policy_number  \
# 976              21                1            2021           1740
# 8454             16                6            2021           1932
# 6544             15                3            2018           2103
# 6877             12                5            2019           3344
# 607               5                6            2018            524
# ...             ...              ...             ...            ...
# 7891             20                8            2019           3402
# 9225              4                5            2018           1767
# 4859             20                6            2020           2978
# 3264             15               11            2020           1348
# 2732              1               10            2018           2555
#
#       primary_cause  product  renewal_frequency  risk_type  secondary_cause  \
# 976               6       14                  4         22               22
# 8454              6       14                  0         23               22
# 6544              6        4                  0         33               20
# 6877              6       26                  1          5               20
# 607               6       14                  1         22               19
# ...             ...      ...                ...        ...              ...
# 7891             11        7                  1         49               30
# 9225              6       14                  0         22               21
# 4859              4       22                  1         30               49
# 3264              6       26                  1          5               21
# 2732              6       27                  1         32               19
#
#       sum_insured
# 976    26924030.0
# 8454     244000.0
# 6544       8500.0
# 6877       8000.0
# 607       90000.0
# ...           ...
# 7891          0.0
# 9225      26850.0
# 4859  118118000.0
# 3264     450000.0
# 2732          0.0
#
# [6563 rows x 15 columns]
#       agent  branch  claim_number  class_of_business  client_type  \
# 976       0       0          7803                 32            0
# 8454      4       0          5671                  9            0
# 6544      7       0          5949                  8            2
# 6877      4       6          8982                 30            2
# 607       3       1          2112                 32            0
# ...     ...     ...           ...                ...          ...
# 7891      4       6          7875                 12            0
# 9225      7       0          4827                 32            0
# 4859      4       4          8908                 11            0
# 3264      7       0          3861                 30            2
# 2732      7       0          6460                  8            2
#
#       loss_date_day  loss_date_month  loss_date_year  policy_number  \
# 976              21                1            2021           1740
# 8454             16                6            2021           1932
# 6544             15                3            2018           2103
# 6877             12                5            2019           3344
# 607               5                6            2018            524
# ...             ...              ...             ...            ...
# 7891             20                8            2019           3402
# 9225              4                5            2018           1767
# 4859             20                6            2020           2978
# 3264             15               11            2020           1348
# 2732              1               10            2018           2555
#
#       primary_cause  product  renewal_frequency  risk_type  secondary_cause  \
# 976               6       14                  4         22               22
# 8454              6       14                  0         23               22
# 6544              6        4                  0         33               20
# 6877              6       26                  1          5               20
# 607               6       14                  1         22               19
# ...             ...      ...                ...        ...              ...
# 7891             11        7                  1         49               30
# 9225              6       14                  0         22               21
# 4859              4       22                  1         30               49
# 3264              6       26                  1          5               21
# 2732              6       27                  1         32               19
#
#       sum_insured
# 976    26924030.0
# 8454     244000.0
# 6544       8500.0
# 6877       8000.0
# 607       90000.0
# ...           ...
# 7891          0.0
# 9225      26850.0
# 4859  118118000.0
# 3264     450000.0
# 2732          0.0
#
# [6563 rows x 15 columns]

# %%
X
# Out:
#       agent  branch  claim_number  class_of_business  client_type  \
# 0         4       5          7439                 30            2
# 1         7       1          3469                  9            2
# 2         1       1          2799                  9            2
# 3         1       0          6448                  8            2
# 4         7       0          4832                 32            0
# ...     ...     ...           ...                ...          ...
# 9371      1       1          2513                 32            0
# 9372      3       1          3338                  8            2
# 9373      3       0          5907                  8            2
# 9374      1       1          3452                  8            2
# 9375      7       0          4128                  9            2
#
#       loss_date_day  loss_date_month  loss_date_year  policy_number  \
# 0                13                5            2021           3070
# 1                13                5            2018           1126
# 2                18                8            2018            630
# 3                20               12            2018           2546
# 4                 7               11            2018           1767
# ...             ...              ...             ...            ...
# 9371              2                9            2019            560
# 9372             12                5            2018           1007
# 9373             28                7            2018           2099
# 9374             16                8            2018           1109
# 9375              7                9            2019           1528
#
#       primary_cause  product  renewal_frequency  risk_type  secondary_cause  \
# 0                 6       26                  0          5               20
# 1                 6        4                  0         31               21
# 2                 6       28                  0         25               22
# 3                 6        4                  0         31               19
# 4                 6       14                  0         22               19
# ...             ...      ...                ...        ...              ...
# 9371              6       14                  1         22               19
# 9372              6        4                  1         31               19
# 9373              6        4                  0         31               27
# 9374              6        4                  0         31               20
# 9375              6       26                  1          5               21
#
#       sum_insured
# 0        300000.0
# 1         16000.0
# 2          3000.0
# 3          6000.0
# 4         26850.0
# ...           ...
# 9371      42000.0
# 9372       6800.0
# 9373       5000.0
# 9374       6000.0
# 9375      10000.0
#
# [9376 rows x 15 columns]
#       agent  branch  claim_number  class_of_business  client_type  \
# 0         4       5          7439                 30            2
# 1         7       1          3469                  9            2
# 2         1       1          2799                  9            2
# 3         1       0          6448                  8            2
# 4         7       0          4832                 32            0
# ...     ...     ...           ...                ...          ...
# 9371      1       1          2513                 32            0
# 9372      3       1          3338                  8            2
# 9373      3       0          5907                  8            2
# 9374      1       1          3452                  8            2
# 9375      7       0          4128                  9            2
#
#       loss_date_day  loss_date_month  loss_date_year  policy_number  \
# 0                13                5            2021           3070
# 1                13                5            2018           1126
# 2                18                8            2018            630
# 3                20               12            2018           2546
# 4                 7               11            2018           1767
# ...             ...              ...             ...            ...
# 9371              2                9            2019            560
# 9372             12                5            2018           1007
# 9373             28                7            2018           2099
# 9374             16                8            2018           1109
# 9375              7                9            2019           1528
#
#       primary_cause  product  renewal_frequency  risk_type  secondary_cause  \
# 0                 6       26                  0          5               20
# 1                 6        4                  0         31               21
# 2                 6       28                  0         25               22
# 3                 6        4                  0         31               19
# 4                 6       14                  0         22               19
# ...             ...      ...                ...        ...              ...
# 9371              6       14                  1         22               19
# 9372              6        4                  1         31               19
# 9373              6        4                  0         31               27
# 9374              6        4                  0         31               20
# 9375              6       26                  1          5               21
#
#       sum_insured
# 0        300000.0
# 1         16000.0
# 2          3000.0
# 3          6000.0
# 4         26850.0
# ...           ...
# 9371      42000.0
# 9372       6800.0
# 9373       5000.0
# 9374       6000.0
# 9375      10000.0
#
# [9376 rows x 15 columns]

# %%
# Make prediction on the test set
test_df = test[main_cols]
predictions = model.predict(test_df)

# # Create a submission file
sub_file = samplesubmission.copy()
sub_file.target = predictions

# Check the distribution of your predictions
plt.figure(figsize=(12, 6))
sns.boxplot(sub_file.target)
plt.title('Predictions Data Distribution');
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-917f1eac4fd6> in <module>
#       5 # # Create a submission file
#       6 sub_file = samplesubmission.copy()
# ----> 7 sub_file.target = predictions
#       8
#       9 # Check the distribution of your predictions
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5492                     object.__setattr__(self, name, value)
#    5493                 elif name in self._info_axis:
# -> 5494                     self[name] = value
#    5495                 else:
#    5496                     object.__setattr__(self, name, value)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3240         """
#    3241         self._ensure_valid_index(value)
# -> 3242         value = self._sanitize_column(key, value)
#    3243         NDFrame._set_item(self, key, value)
#    3244
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3897
#    3898             # turn me into an ndarray
# -> 3899             value = sanitize_index(value, self.index)
#    3900             if not isinstance(value, (np.ndarray, Index)):
#    3901                 if isinstance(value, list) and len(value) > 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index)
#     749     """
#     750     if len(data) != len(index):
# --> 751         raise ValueError(
#     752             "Length of values "
#     753             f"({len(data)}) "
#
# ValueError: Length of values (843369) does not match length of index (4019)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-917f1eac4fd6> in <module>
#       5 # # Create a submission file
#       6 sub_file = samplesubmission.copy()
# ----> 7 sub_file.target = predictions
#       8
#       9 # Check the distribution of your predictions
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5492                     object.__setattr__(self, name, value)
#    5493                 elif name in self._info_axis:
# -> 5494                     self[name] = value
#    5495                 else:
#    5496                     object.__setattr__(self, name, value)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3240         """
#    3241         self._ensure_valid_index(value)
# -> 3242         value = self._sanitize_column(key, value)
#    3243         NDFrame._set_item(self, key, value)
#    3244
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3897
#    3898             # turn me into an ndarray
# -> 3899             value = sanitize_index(value, self.index)
#    3900             if not isinstance(value, (np.ndarray, Index)):
#    3901                 if isinstance(value, list) and len(value) > 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index)
#     749     """
#     750     if len(data) != len(index):
# --> 751         raise ValueError(
#     752             "Length of values "
#     753             f"({len(data)}) "
#
# ValueError: Length of values (843369) does not match length of index (4019)

# %%
# Preview the sub_file
sub_file.head()

# %%
# Write to csv file to submit to Zindi
sub_file.to_csv("Baseline.csv", index = False)
